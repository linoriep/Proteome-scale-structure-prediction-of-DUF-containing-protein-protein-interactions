# %%
from pathlib import Path
import sys
ROOT = Path.cwd().resolve()
if ROOT.name == 'notebooks': ROOT = ROOT.parent
sys.path.insert(0, str(ROOT / 'src'))
from dufppi.model import cross_validate, load_training_data

# %%
X, y, names = load_training_data(ROOT / 'data/model/training_labels_channels.tsv.gz')
oof, folds, metrics = cross_validate(X, y)
metrics
